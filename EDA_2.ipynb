# %% [markdown]
# ## <span style='color:#ffb5c0'>**Exploratory Data Analysis, February 20th, 2026**

# %%
import pandas as pd
import numpy as np

# %%
import holoviews as hv
import hvplot.pandas
from holoviews import opts
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a2661a0e-2842-4c15-b420-5ae5bced1774'>
#   <div id="f09f94a5-75e8-4aa3-a608-646e90d7bb87" data-root-id="a2661a0e-2842-4c15-b420-5ae5bced1774" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9a3b928a-d4b4-43ce-9ef8-fc90ec035985":{"version":"3.8.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"4c122ae1-c692-4809-b0ea-3a597a16eeb3","attributes":{"notifications":{"type":"object","name":"Notifications","id":"bd1bd0cf-1c19-4dc5-9877-3505000cf830"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a2661a0e-2842-4c15-b420-5ae5bced1774"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"97fd9723-cec2-4733-84fa-9f23dc108116","attributes":{"plot_id":"a2661a0e-2842-4c15-b420-5ae5bced1774","comm_id":"2837a20c89094520b18b42c3356ed073","client_comm_id":"338272f4823a499f8e622f0af37acbc1"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"9a3b928a-d4b4-43ce-9ef8-fc90ec035985","roots":{"a2661a0e-2842-4c15-b420-5ae5bced1774":"f09f94a5-75e8-4aa3-a608-646e90d7bb87"},"root_ids":["a2661a0e-2842-4c15-b420-5ae5bced1774"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
data = pd.read_csv("ELA_data_2013_2023.csv")

# %% [markdown]
# ### <span style='color:#ffb5c0'>**Data Feasibility Review & Data Cleaning/Preprocessing**

# %% [markdown]
# The initial data contains 626,462 rows and 18 columns. After filtering for years 2018, 2019, and 2022, the data contains 220,443 rows. Almost all columns do not have missing values, with the exception for school name. This is due to the data containing citywide and district level metrics, so school name is not applicable.
#
# The data was filtered to contain only years surrounding the COVID-19 pandemic, as this is the time period of interest. Unfortunately, data was not given for the years 2020 and 2021, due to cancelled and optional testing, respectively. All scores and levels (number and percentages) were converted to floats. The year was converted to an object. Groups with five or less tested students were suppressed with a value "s". Within this data, 58,872 rows are missing observations for scores and level breakdowns. These observations have been omitted.

# %%
from data_cleaning import cleaning_data, change_variable_type
school_data = cleaning_data(data) # filter for year, rename some vars

# convert num columns
cols = ['mean_scale_score','level_1_count','level_2_count','level_3_count', 'level_4_count', 'level_4_percentage', 'level_3_4_count',
        'level_1_percentage','level_2_percentage','level_3_percentage','level_4_percentage','level_3_4_percentage']
school_data = change_variable_type(school_data,cols)
# change year to ob
school_data['Year'] = school_data['Year'].astype('object')

# %%
# school_data.info()

# %%
# school_data_filtered = school_data[
#     ~(school_data['Report Category'].isin(['Citywide','School','Borough']))]

school_data_filtered = school_data[
    (school_data['Report Category'].isin(['District'])) &
    (school_data['Grade'] == 'All Grades') &
    (school_data['Student Category'] == 'All Students')
    ]

# %% [markdown]
# ### <span style='color:#ffb5c0'>**Ethics and Bias Considerations** </span>

# %% [markdown]
# This data is very heavily balanced regarding different socioeconomic categories. There are some disparities with gender by ethnicity, however these indicators will not be used. The same can be said for grade, where there is sufficient distribution.

# %% [markdown]
# ### <span style='color:#ffb5c0'> **Poverty Data, by School District**

# %% [markdown]
# Citizen's Committee for Children of New York <br>
# https://data.cccnewyork.org/data/map/1370/student-economic-status#1370/a/5/1610/127/a/a

# %%
# eco = pd.read_csv('student_economic_status.csv')

# %%
# eco['TimeFrame'] = eco['TimeFrame'].astype('Int64')
# eco['TimeFrame'] = eco['TimeFrame'].astype('object')

# %%
# eco_filter = eco[
#     (eco['TimeFrame'] == 2019) &
#     (eco['DataFormat'] == 'Percent') &
#     ~(eco['Fips'].isin(['3651000', '36061', '36005', '36047', '36081', '36085']))]

# %%
# eco_filter['Fips'] = eco_filter['Fips'].replace({'SD1':'1', 'SD2':'2', 'SD3':'3', 'SD4':'4', 'SD5':'5', 'SD6':'6', 'SD7':'7', 'SD8':'8', 'SD9':'9',
#                                          'SD10':'10', 'SD11':'11', 'SD12':'12', 'SD13':'13', 'SD14':'14', 'SD15':'15', 'SD16':'16', 'SD17':'17', 'SD18':'18',
#                                          'SD19':'19', 'SD20':'20', 'SD21':'21', 'SD22':'22', 'SD23':'23', 'SD24':'24', 'SD25':'25', 'SD26':'26', 'SD27':'27', 'SD28':'28', 'SD29':'29',
#                                          'SD30':'30', 'SD31':'31', 'SD32':'32'})

# %%
# eco_filter= eco_filter.rename(columns = {'Fips':'District'})
# school_data_filtered= school_data_filtered.rename(columns = {'Geographic Subdivision':'District'})

# %%
# merged_data = school_data_filtered.merge(eco_filter, on='District', how='left')

# %%
# nyc_poverty_percent = 0.7276

# %%
# def categorize_poverty(row):
#     if row['Data'] >= nyc_poverty_percent:
#         return '1'
#     else:
#         return '0'

# %%
# merged_data['Poverty_Category'] = merged_data.apply(categorize_poverty, axis=1)

# %%
# p_data= (merged_data.groupby(['Year','Poverty_Category'])[
#     ['level_1_percentage',
#      'level_2_percentage',
#      'level_3_percentage',
#      'level_4_percentage',
#      'level_3_4_percentage',
#      'mean_scale_score'
#      ]
# ].mean())

# p1= p_data.hvplot.line(
#     x = 'Year',
#     y = 'mean_scale_score',
#     by = 'Poverty_Category'
# ).opts(ylabel = 'Level 1 %')

# p1

# %%
# p_data= (merged_data.groupby(['Year','Poverty_Category'])[
#     ['level_1_percentage',
#      'level_2_percentage',
#      'level_3_percentage',
#      'level_4_percentage',
#      'level_3_4_percentage',
#      'mean_scale_score'
#      ]
# ].mean())

# p1= p_data.hvplot.line(
#     x = 'Year',
#     y = 'level_1_percentage',
#     by = 'Poverty_Category'
# ).opts(ylabel = 'Level 1 %')


# p2 = p_data.hvplot.line(
#     x = 'Year',
#     y = 'level_2_percentage',
#     by = 'Poverty_Category'
# ).opts(ylabel = 'Level 2 %')

# p3 = p_data.hvplot.line(
#     x = 'Year',
#     y = 'level_3_percentage',
#     by = 'Poverty_Category'
# ).opts(ylabel = 'Level 3 %')

# p4 = p_data.hvplot.line(
#     x = 'Year',
#     y = 'level_4_percentage',
#     by = 'Poverty_Category'
# ).opts(ylabel = 'Level 4 %')

# p5 = p_data.hvplot.line(
#     x = 'Year',
#     y = 'level_3_4_percentage',
#     by = 'Poverty_Category'
# ).opts(ylabel = 'Level 3 & 4 %')

# p6 = p_data.hvplot.line(
#     x = 'Year',
#     y = 'mean_scale_score',
#     by = 'Poverty_Category'
# ).opts(ylabel = 'Mean Scale Score')


# layout1 = (p1 + p2 + p3 + p4 + p5 + p6).cols(2)
# layout1

# %%
# print(school_data['school_name'].nunique())

# %% [markdown]
# ### <span style='color:#ffb5c0'> **Poverty Data, for District Level Information**

# %%
district_poverty = pd.read_excel('Demographic_Snapshot_2017-18_to_2021-22__Public_.xlsx', sheet_name = 'District')

# %%
district_poverty
# Out:
#      Administrative District     Year  Total Enrollment  Grade 3K  \
# 0                          1  2017-18             11632         0
# 1                          1  2018-19             11376         0
# 2                          1  2019-20             11506       211
# 3                          1  2020-21             11021       209
# 4                          1  2021-22             10327       347
# ..                       ...      ...               ...       ...
# 170                       84  2017-18            113528         0
# 171                       84  2018-19            119551         0
# 172                       84  2019-20            129668         0
# 173                       84  2020-21            138648         0
# 174                       84  2021-22            139752         0
#
#      Grade PK (Half Day & Full Day)  Grade K  Grade 1  Grade 2  Grade 3  \
# 0                               800      851      846      854      862
# 1                               759      799      850      816      838
# 2                               749      812      782      848      813
# 3                               623      728      762      746      787
# 4                               524      685      701      686      680
# ..                              ...      ...      ...      ...      ...
# 170                             533    11445    12016    11447    10857
# 171                             524    12001    12103    11765    10955
# 172                             572    13217    13130    12313    11798
# 173                             636    13122    13775    13331    12526
# 174                             863    12299    13122    13154    12688
#
#      Grade 4  ...   % White  # Missing Race/Ethnicity Data  \
# 0        839  ...  0.173831                             29
# 1        839  ...  0.179764                             38
# 2        818  ...  0.178689                            126
# 3        775  ...  0.180746                            101
# 4        707  ...  0.180014                             29
# ..       ...  ...       ...                            ...
# 170    10032  ...  0.043848                            280
# 171    10196  ...  0.043488                            281
# 172    10928  ...  0.042539                            269
# 173    11982  ...  0.043650                            445
# 174    11963  ...  0.043692                            495
#
#      % Missing Race/Ethnicity Data  # Students with Disabilities  \
# 0                         0.002493                          2528
# 1                         0.003340                          2597
# 2                         0.010951                          2593
# 3                         0.009164                          2501
# 4                         0.002808                          2355
# ..                             ...                           ...
# 170                       0.002466                         20002
# 171                       0.002350                         21281
# 172                       0.002075                         23257
# 173                       0.003210                         25299
# 174                       0.003542                         25075
#
#      % Students with Disabilities  # English Language Learners  \
# 0                        0.217331                         1016
# 1                        0.228288                          966
# 2                        0.225361                          919
# 3                        0.226930                          919
# 4                        0.228043                          814
# ..                            ...                          ...
# 170                      0.176186                         7859
# 171                      0.178008                         8264
# 172                      0.179358                         9256
# 173                      0.182469                        10755
# 174                      0.179425                        12655
#
#      % English Language Learners  # Poverty  % Poverty  Economic Need Index
# 0                       0.087345       7682   0.660420             0.670163
# 1                       0.084916       7314   0.642932             0.661232
# 2                       0.079871       7419   0.644794             0.676958
# 3                       0.083386       7087   0.643045             0.670118
# 4                       0.078823       6463   0.625835             0.653216
# ..                           ...        ...        ...                  ...
# 170                     0.069225      92292   0.812945             0.755627
# 171                     0.069125      96585   0.807898             0.753894
# 172                     0.071382     104010   0.802125             0.781033
# 173                     0.077571     112037   0.808068             0.780144
# 174                     0.090553     111488   0.797756             0.774605
#
# [175 rows x 43 columns]

# %%
cols_to_keep = ['Administrative District','Year','% Poverty']
district_poverty_filtered = district_poverty[
    (district_poverty['Year'] == '2018-19') & 
    ~(district_poverty['Administrative District'].isin([75,79,84]))][cols_to_keep]

# %%
district_poverty_filtered['Administrative District'] = district_poverty_filtered['Administrative District'].astype('object')

# %%
district_poverty_filtered['% Poverty'] = district_poverty_filtered['% Poverty'].replace({'Above 95%':'0.95'})

# %%
district_level_data = school_data[
    (school_data['Report Category'].isin(['District'])) &
    (school_data['Grade'] == 'All Grades') &
    (school_data['Student Category'] == 'All Students')
    ]

# %%
district_level_data= district_level_data.rename(columns = {'Geographic Subdivision':'Administrative District'})

# %%
district_poverty_filtered
# Out:
#     Administrative District     Year  % Poverty
# 1                         1  2018-19   0.642932
# 6                         2  2018-19   0.531863
# 11                        3  2018-19   0.489436
# 16                        4  2018-19   0.813852
# 21                        5  2018-19   0.818708
# 26                        6  2018-19   0.853175
# 31                        7  2018-19   0.916370
# 36                        8  2018-19   0.832162
# 41                        9  2018-19   0.924517
# 46                       10  2018-19   0.831589
# 51                       11  2018-19   0.783517
# 56                       12  2018-19   0.921567
# 61                       13  2018-19   0.647896
# 66                       14  2018-19   0.726526
# 71                       15  2018-19   0.565744
# 76                       16  2018-19   0.838399
# 81                       17  2018-19   0.800582
# 86                       18  2018-19   0.774557
# 91                       19  2018-19   0.883512
# 96                       20  2018-19   0.771452
# 101                      21  2018-19   0.728727
# 106                      22  2018-19   0.703402
# 111                      23  2018-19   0.898278
# 116                      24  2018-19   0.761976
# 121                      25  2018-19   0.690140
# 126                      26  2018-19   0.574056
# 131                      27  2018-19   0.753754
# 136                      28  2018-19   0.694165
# 141                      29  2018-19   0.732208
# 146                      30  2018-19   0.704468
# 151                      31  2018-19   0.578126
# 156                      32  2018-19   0.890199

# %%
# Diagnostics: why merge produced empty '% Poverty' values
print('--- DIAGNOSTICS: Administrative District dtypes and samples ---')
left = district_level_data['Administrative District'].astype(str).str.strip()
right = district_poverty_filtered['Administrative District'].astype(str).str.strip()
print('left dtype:', left.dtype, 'right dtype:', right.dtype)
print('left sample:', left.unique()[:20])
print('right sample:', right.unique()[:20])
s1 = set(left.unique())
s2 = set(right.unique())
print('common keys count:', len(s1 & s2))
print('examples left-not-right:', list(s1 - s2)[:10])

# Normalize common issues: whitespace, 'SD' prefix, trailing .0 from floats, and 'District' words
district_level_data['Administrative District'] = (
    district_level_data['Administrative District']
    .astype(str).str.strip()
    .str.replace(r'(^SD|District\s*)', '', regex=True)
    .str.replace(r'\.0$', '', regex=True)
)
district_poverty_filtered['Administrative District'] = (
    district_poverty_filtered['Administrative District']
    .astype(str).str.strip()
    .str.replace(r'(^SD|District\s*)', '', regex=True)
    .str.replace(r'\.0$', '', regex=True)
)
# Coerce purely-numeric-looking strings to canonical integer-like strings (e.g., '1.0' -> '1')
def _norm_num(x):
    try:
        return str(int(float(x)))
    except Exception:
        return x
district_level_data['Administrative District'] = district_level_data['Administrative District'].apply(_norm_num)
district_poverty_filtered['Administrative District'] = district_poverty_filtered['Administrative District'].apply(_norm_num)

# Re-run merge after normalization
merged_district = district_level_data.merge(
    district_poverty_filtered[['Administrative District', '% Poverty']],
    on='Administrative District',
    how='left'
)
print('merge complete; fraction missing % Poverty:', merged_district['% Poverty'].isna().mean())
print('examples unmatched keys (first 20):', merged_district[merged_district['% Poverty'].isna()]['Administrative District'].unique()[:20])

# %%
merged_district
# Out:
#    Report Category Administrative District school_name       Grade  Year  \
# 0         District                       1         NaN  All Grades  2022
# 1         District                       1         NaN  All Grades  2019
# 2         District                       2         NaN  All Grades  2022
# 3         District                       2         NaN  All Grades  2019
# 4         District                       3         NaN  All Grades  2022
# ..             ...                     ...         ...         ...   ...
# 59        District                      30         NaN  All Grades  2019
# 60        District                      31         NaN  All Grades  2022
# 61        District                      31         NaN  All Grades  2019
# 62        District                      32         NaN  All Grades  2022
# 63        District                      32         NaN  All Grades  2019
#
#    Student Category  number_tested  mean_scale_score  level_1_count  \
# 0      All Students           3283             605.0          650.0
# 1      All Students           4103             605.0          794.0
# 2      All Students          12669             614.0         1024.0
# 3      All Students          15264             613.0         1325.0
# 4      All Students           6319             609.0          919.0
# ..              ...            ...               ...            ...
# 59     All Students          17880             604.0         3288.0
# 60     All Students          23476             604.0         4336.0
# 61     All Students          26058             603.0         5243.0
# 62     All Students           4023             595.0         1340.0
# 63     All Students           5258             594.0         1715.0
#
#     level_1_percentage  level_2_count  level_2_percentage  level_3_count  \
# 0                 19.8          871.0                26.5          793.0
# 1                 19.4         1055.0                25.7         1079.0
# 2                  8.1         2228.0                17.6         3932.0
# 3                  8.7         2528.0                16.6         5076.0
# 4                 14.5         1324.0                21.0         1760.0
# ..                 ...            ...                 ...            ...
# 59                18.4         4809.0                26.9         5322.0
# 60                18.5         6265.0                26.7         6975.0
# 61                20.1         7077.0                27.2         7901.0
# 62                33.3         1228.0                30.5          906.0
# 63                32.6         1681.0                32.0         1228.0
#
#     level_3_percentage  level_4_count  level_4_percentage  level_3_4_count  \
# 0                 24.2          969.0                29.5           1762.0
# 1                 26.3         1175.0                28.6           2254.0
# 2                 31.0         5485.0                43.3           9417.0
# 3                 33.3         6335.0                41.5          11411.0
# 4                 27.9         2316.0                36.7           4076.0
# ..                 ...            ...                 ...              ...
# 59                29.8         4461.0                24.9           9783.0
# 60                29.7         5900.0                25.1          12875.0
# 61                30.3         5837.0                22.4          13738.0
# 62                22.5          549.0                13.6           1455.0
# 63                23.4          634.0                12.1           1862.0
#
#     level_3_4_percentage  % Poverty
# 0                   53.7        NaN
# 1                   54.9        NaN
# 2                   74.3        NaN
# 3                   74.8        NaN
# 4                   64.5        NaN
# ..                   ...        ...
# 59                  54.7        NaN
# 60                  54.8        NaN
# 61                  52.7        NaN
# 62                  36.2        NaN
# 63                  35.4        NaN
#
# [64 rows x 19 columns]

# %%
def categorize_poverty(row):
    if row['% Poverty'] >= nyc_poverty_percent:
        return '1'
    else:
        return '0'
    
nyc_poverty_percent = 0.74

# %%
merged_district['% Poverty'] = merged_district['% Poverty'].astype(float)
merged_district['Poverty_Category'] = merged_district.apply(categorize_poverty, axis=1) 
merged_district['% Poverty'] = merged_district['% Poverty'].round(3)

# %%
p_data_dis= (merged_district.groupby(['Year','Poverty_Category'])[
    ['level_1_percentage',
     'level_2_percentage',
     'level_3_percentage',
     'level_4_percentage',
     'level_3_4_percentage',
     'mean_scale_score'
     ]
].mean())

p1= p_data_dis.hvplot.line(
    x = 'Year',
    y = 'level_1_percentage',
    by = 'Poverty_Category'
).opts(ylabel = 'Level 1 %')


p2 = p_data_dis.hvplot.line(
    x = 'Year',
    y = 'level_2_percentage',
    by = 'Poverty_Category'
).opts(ylabel = 'Level 2 %')

p3 = p_data_dis.hvplot.line(
    x = 'Year',
    y = 'level_3_percentage',
    by = 'Poverty_Category'
).opts(ylabel = 'Level 3 %')

p4 = p_data_dis.hvplot.line(
    x = 'Year',
    y = 'level_4_percentage',
    by = 'Poverty_Category'
).opts(ylabel = 'Level 4 %')

p5 = p_data_dis.hvplot.line(
    x = 'Year',
    y = 'level_3_4_percentage',
    by = 'Poverty_Category'
).opts(ylabel = 'Level 3 & 4 %')

p6 = p_data_dis.hvplot.line(
    x = 'Year',
    y = 'mean_scale_score',
    by = 'Poverty_Category'
).opts(ylabel = 'Mean Scale Score')


layout1 = (p1 + p2 + p3 + p4 + p5 + p6).cols(2)
layout1
# Out:
# :Layout
#    .NdOverlay.I   :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (level_1_percentage)
#    .NdOverlay.II  :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (level_2_percentage)
#    .NdOverlay.III :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (level_3_percentage)
#    .NdOverlay.IV  :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (level_4_percentage)
#    .NdOverlay.V   :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (level_3_4_percentage)
#    .NdOverlay.VI  :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (mean_scale_score)

# %% [markdown]
# ### <span style='color:#ffb5c0'> **Poverty Data, for School Level Information**

# %% [markdown]
# New York City OpenData Demographic Snapshot <br>
# https://data.cityofnewyork.us/Education/2017-18-2021-22-Demographic-Snapshot/c7ru-d68s/about_data

# %%
school_poverty = pd.read_excel('Demographic_Snapshot_2017-18_to_2021-22__Public_.xlsx', sheet_name = 'School')

# %%
cols_to_keep = ['DBN','School Name','Year','% Poverty']
school_poverty_filtered = school_poverty[
    (school_poverty['Year'] == '2018-19')][cols_to_keep]

# %%
# all schools w poverty levels > 0.95 were labelled as "Above 95%", puts 0.95 inplace
school_poverty_filtered['% Poverty'] = school_poverty_filtered['% Poverty'].replace({'Above 95%':'0.95'})

# %% [markdown]
# **Citywide Poverty % for 2018-19 school year was 74%**

# %%
school_level_data = school_data[
    (school_data['Report Category'].isin(['School'])) &
    (school_data['Grade'] == 'All Grades') &
    (school_data['Student Category'] == 'All Students')
    ]

# %%
school_poverty_filtered['School Name'].nunique()
# Out:
# 1821

# %%
school_level_data['school_name'].nunique()
# Out:
# 1119

# %%
school_level_data= school_level_data.rename(columns = {'Geographic Subdivision':'DBN'})

# %%
merged = school_level_data.merge(
    school_poverty_filtered[['DBN', '% Poverty']],  # keep only needed columns
    on='DBN',
    how='left'
)

# %%
def categorize_poverty(row):
    if row['% Poverty'] >= nyc_poverty_percent:
        return '1'
    else:
        return '0'
    
nyc_poverty_percent = 0.74

# %%
merged['% Poverty'] = merged['% Poverty'].astype(float)

# %%
merged['Poverty_Category'] = merged.apply(categorize_poverty, axis=1) 
merged['% Poverty'] = merged['% Poverty'].round(3)

# %%
p_data= (merged.groupby(['Year','Poverty_Category'])[
    ['level_1_percentage',
     'level_2_percentage',
     'level_3_percentage',
     'level_4_percentage',
     'level_3_4_percentage',
     'mean_scale_score'
     ]
].mean())

p1= p_data.hvplot.line(
    x = 'Year',
    y = 'level_1_percentage',
    by = 'Poverty_Category'
).opts(ylabel = 'Level 1 %')


p2 = p_data.hvplot.line(
    x = 'Year',
    y = 'level_2_percentage',
    by = 'Poverty_Category'
).opts(ylabel = 'Level 2 %')

p3 = p_data.hvplot.line(
    x = 'Year',
    y = 'level_3_percentage',
    by = 'Poverty_Category'
).opts(ylabel = 'Level 3 %')

p4 = p_data.hvplot.line(
    x = 'Year',
    y = 'level_4_percentage',
    by = 'Poverty_Category'
).opts(ylabel = 'Level 4 %')

p5 = p_data.hvplot.line(
    x = 'Year',
    y = 'level_3_4_percentage',
    by = 'Poverty_Category'
).opts(ylabel = 'Level 3 & 4 %')

p6 = p_data.hvplot.line(
    x = 'Year',
    y = 'mean_scale_score',
    by = 'Poverty_Category'
).opts(ylabel = 'Mean Scale Score')


layout1 = (p1 + p2 + p3 + p4 + p5 + p6).cols(2)
layout1
# Out:
# :Layout
#    .NdOverlay.I   :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (level_1_percentage)
#    .NdOverlay.II  :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (level_2_percentage)
#    .NdOverlay.III :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (level_3_percentage)
#    .NdOverlay.IV  :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (level_4_percentage)
#    .NdOverlay.V   :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (level_3_4_percentage)
#    .NdOverlay.VI  :NdOverlay   [Poverty_Category]
#       :Curve   [Year]   (mean_scale_score)

# %%
merged.hvplot.hist(
    y = '% Poverty',
    by = 'Year',
    bins = 30,
    title = 'Poverty % Distribution - 2019 and 2022'
)
# Out:
# :NdOverlay   [Year]
#    :Histogram   [% Poverty]   (Count)

# %% [markdown]
# Poverty percentage is left-skewed. This does not entirely effect TWFE DID analysis, normality is not an assumption.

# %%
merged.hvplot.scatter(
    x  = '% Poverty',
    y = 'mean_scale_score',
    by = 'Year'
).opts(xlabel='Poverty %', ylabel='Mean Score', width = 900, height = 600)
# Out:
# :NdOverlay   [Year]
#    :Scatter   [% Poverty]   (mean_scale_score)
